# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files

# Open file upload dialog
uploaded = files.upload()

# Move the uploaded file to your desired path in Drive
for filename in uploaded.keys():
    file_path = f'/content/drive/MyDrive/{filename}'
    with open(file_path, 'wb') as f:
        f.write(uploaded[filename])

    print(f"✅ File uploaded successfully to: {file_path}")
# Out:
#      <input type="file" id="files-7e2bc676-6530-4a60-a4f8-fc32346171d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e2bc676-6530-4a60-a4f8-fc32346171d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# First 5 rows
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0      10107.0             30.0      95.70              2.0  2871.00
# 1      10121.0             34.0      81.35              5.0  2765.90
# 2      10134.0             41.0      94.74              2.0  3884.34
# 3      10145.0             45.0      83.26              6.0  3746.70
# 4      10159.0             49.0     100.00             14.0  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...             PHONE  \
# 0   2/24/2003 0:00  Shipped     1.0       2.0   2003.0  ...        2125557818
# 1  05/07/2003 0:00  Shipped     2.0       5.0   2003.0  ...        26.47.1555
# 2  07/01/2003 0:00  Shipped     3.0       7.0   2003.0  ...  +33 1 46 62 7555
# 3   8/25/2003 0:00  Shipped     3.0       8.0   2003.0  ...        6265557265
# 4  10/10/2003 0:00  Shipped     4.0      10.0   2003.0  ...        6505551386
#
#                     ADDRESSLINE1           CITY    STATE POSTALCODE COUNTRY  \
# ...

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 2818          NaN              NaN        NaN              NaN    NaN
# 2819          NaN              NaN        NaN              NaN    NaN
# 2820          NaN              NaN        NaN              NaN    NaN
# 2821          NaN              NaN        NaN              NaN    NaN
# 2822          NaN              NaN        NaN              NaN    NaN
#
#      ORDERDATE STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... PHONE  ADDRESSLINE1  \
# 2818       NaN    NaN     NaN       NaN      NaN  ...   NaN           NaN
# 2819       NaN    NaN     NaN       NaN      NaN  ...   NaN           NaN
# 2820       NaN    NaN     NaN       NaN      NaN  ...   NaN           NaN
# 2821       NaN    NaN     NaN       NaN      NaN  ...   NaN           NaN
# 2822       NaN    NaN     NaN       NaN      NaN  ...   NaN           NaN
#
#      CITY    STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
df.info()

# Summary statistics
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       599 non-null    float64
#  1   QUANTITYORDERED   599 non-null    float64
#  2   PRICEEACH         599 non-null    float64
#  3   ORDERLINENUMBER   599 non-null    float64
#  4   SALES             599 non-null    float64
#  5   ORDERDATE         599 non-null    object
#  6   STATUS            599 non-null    object
#  7   QTR_ID            599 non-null    float64
#  8   MONTH_ID          599 non-null    float64
#  9   YEAR_ID           599 non-null    float64
#  10  PRODUCTLINE       599 non-null    object
#  11  MSRP              599 non-null    float64
#  12  PRODUCTCODE       599 non-null    object
#  13  CUSTOMERNAME      599 non-null    object
#  14  PHONE             599 non-null    object
#  15  ADDRESSLINE1      599 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER         2224
# QUANTITYORDERED     2224
# PRICEEACH           2224
# ORDERLINENUMBER     2224
# SALES               2224
# ORDERDATE           2224
# STATUS              2224
# QTR_ID              2224
# MONTH_ID            2224
# YEAR_ID             2224
# PRODUCTLINE         2224
# MSRP                2224
# PRODUCTCODE         2224
# CUSTOMERNAME        2224
# PHONE               2224
# ADDRESSLINE1        2224
# CITY                2224
# STATE                  0
# POSTALCODE          2251
# COUNTRY             2224
# TERRITORY           2462
# CONTACTLASTNAME     2224
# CONTACTFIRSTNAME    2224
# DEALSIZE            2224
# dtype: int64

# %%
if 'ADDRESSLINE2' in df.columns:
    df = df.drop(columns=['ADDRESSLINE2'])

# Fill missing values in 'STATE' column with 'Unknown'
df['STATE'] = df['STATE'].fillna('Unknown')

# %%
# Add a new column: TotalPrice = Quantity * Price
df['TotalPrice'] = df['QUANTITYORDERED'] * df['PRICEEACH']

# %%
# Drop column not needed
df = df.drop(columns=['POSTALCODE'])

# %%
# Filter orders greater than $5000
high_value_orders = df[df['TotalPrice'] > 5000]
high_value_orders.head()
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 25       10417.0             66.0      100.0              2.0   7516.08
# 104      10403.0             66.0      100.0              9.0  11886.60
# 105      10417.0             56.0      100.0              4.0   9218.16
# 131      10400.0             64.0      100.0              9.0   9661.44
# 260      10341.0             55.0      100.0              8.0   8118.55
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 25    5/13/2005 0:00  Disputed     2.0       5.0   2005.0  ...
# 104  04/08/2005 0:00   Shipped     2.0       4.0   2005.0  ...
# 105   5/13/2005 0:00  Disputed     2.0       5.0   2005.0  ...
# 131  04/01/2005 0:00   Shipped     2.0       4.0   2005.0  ...
# 260  11/24/2004 0:00   Shipped     4.0      11.0   2004.0  ...
#
#               PHONE                  ADDRESSLINE1       CITY    STATE  \
# 25   (91) 555 94 44            C/ Moralzarzal, 86     Madrid  Unknown
# ...

# %%
# Group by Country and calculate total sales
grouped_sales = df.groupby('COUNTRY')['SALES'].sum().reset_index()

# Sort by total sales descending
grouped_sales = grouped_sales.sort_values(by='SALES', ascending=False)

grouped_sales
# Out:
#         COUNTRY       SALES
# 18          USA  1069576.24
# 6        France   314843.66
# 14        Spain   222953.35
# 0     Australia   173712.22
# 17           UK   118569.09
# 9         Italy   112699.21
# 11       Norway    99618.61
# 13    Singapore    96204.07
# 1       Austria    86231.60
# 4       Denmark    84206.69
# 5       Finland    82380.15
# 15       Sweden    70827.00
# 7       Germany    60822.97
# 10        Japan    57833.19
# 3        Canada    55326.33
# 16  Switzerland    37301.11
# 12  Philippines    26096.34
# 8       Ireland    16940.26
# 2       Belgium     9133.59
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# grouped_sales['SALES'].plot(kind='hist', bins=20, title='SALES')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
# Multiple aggregation on one column
df.groupby('COUNTRY')['SALES'].agg(['sum', 'mean', 'count']).reset_index()
# Out:
#         COUNTRY         sum         mean  count
# 0     Australia   173712.22  4136.005238     42
# 1       Austria    86231.60  4538.505263     19
# 2       Belgium     9133.59  4566.795000      2
# 3        Canada    55326.33  4610.527500     12
# 4       Denmark    84206.69  5262.918125     16
# 5       Finland    82380.15  4119.007500     20
# 6        France   314843.66  4497.766571     70
# 7       Germany    60822.97  4344.497857     14
# 8       Ireland    16940.26  5646.753333      3
# 9         Italy   112699.21  5122.691364     22
# 10        Japan    57833.19  5257.562727     11
# 11       Norway    99618.61  4331.243913     23
# 12  Philippines    26096.34  5219.268000      5
# 13    Singapore    96204.07  5659.062941     17
# 14        Spain   222953.35  4743.688298     47
# 15       Sweden    70827.00  4721.800000     15
# 16  Switzerland    37301.11  3730.111000     10
# 17           UK   118569.09  4742.763600     25
# 18          USA  1069576.24  4732.638230    226
# ...
